# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import seaborn as sns
# Out:
# /home/pranjal/.local/share/virtualenvs/crime-analysis-report-pk3Cf-oK/lib/python3.7/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df = pd.read_csv('data_final.csv')
df.drop(['State'], axis = 1, inplace = True)
df["Crime Rate"] = df['Crimes']
df.drop(['Crimes'], axis = 1, inplace = True)
df.head()
# Out:
#    Year  Literacy Rate  Int Border  Crime Rate
# 0  2001      56.962286           0         270
# 1  2001      52.921714           1           0
# 2  2001      62.805714           1          18
# 3  2001      48.842143           1          83
# 4  2001      58.478571           0         585

# %%
X = df.iloc[:, 1:2]
y = df.iloc[:, 3:4]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

regressor = LinearRegression()  
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Root Mean Squared Error: 1937.1350444130892

# %%
sns.pairplot(df.drop['Year'], axis = 1)

# %%
df.drop(['Year'], axis=1).corr()
# Out:
#                Literacy Rate  Int Border  Crime Rate
# Literacy Rate       1.000000   -0.256201   -0.061331
# Int Border         -0.256201    1.000000   -0.117059
# Crime Rate         -0.061331   -0.117059    1.000000
