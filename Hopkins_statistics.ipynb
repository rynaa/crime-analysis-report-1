# %%
from sklearn.neighbors import BallTree
import numpy as np
import pandas as pd
from sklearn.preprocessing import scale
# Out:
# /home/pranjal/.local/share/virtualenvs/crime-analysis-report-pk3Cf-oK/lib/python3.7/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# The Hopkins statistic is a way of measuring the cluster tendency of a data set. It belongs to the family of sparse sampling tests.
#
# Dataset used : [https://archive.ics.uci.edu/ml/datasets/Absenteeism+at+work](https://archive.ics.uci.edu/ml/datasets/Absenteeism+at+work)

# %%
# dataset = pd.read_csv('./Absenteeism_at_work.csv', sep=';')
dataset = pd.read_pickle('./state_clubbed_df.pickle')
sampling_size = 350

# %%
rows, columns = dataset.shape
print ("Total rows : {}\t Total columns: {}".format(rows, columns))
# Out:
# Total rows : 527	 Total columns: 13

# %%
dataset.head()
# Out:
#                state  year  murder   rape  foeticide  \
# 0     andhra pradesh  2001    35.0   84.0        0.0
# 1  arunachal pradesh  2001     0.0    0.0        0.0
# 2              assam  2001     0.0    0.0        0.0
# 3              bihar  2001     2.0   16.0        0.0
# 4       chhattisgarh  2001    14.0  150.0        5.0
#
#    kidnapping and abduction  abetment of suicide  exposure and abandonment  \
# 0                      57.0                  7.0                      22.0
# 1                       0.0                  0.0                       0.0
# 2                      18.0                  0.0                       0.0
# 3                      26.0                  0.0                       1.0
# 4                      46.0                  1.0                      15.0
#
#    procuration of minor girls  selling girls for prostitution  \
# 0                        12.0                             0.0
# 1                         0.0                             0.0
# 2                         0.0                             0.0
# 3                        16.0                             1.0
# 4                         0.0                             0.0
#
#    prohibition of child marriage act  other crimes  total
# 0                                6.0          47.0  270.0
# 1                                0.0           0.0    0.0
# 2                                0.0           0.0   18.0
# 3                                2.0          18.0   83.0
# 4                                0.0         354.0  585.0

# %%
# Scaling and Preprocessing the dataset

dataset.drop(['state', 'year', 'total'], axis=1, inplace=True)
dataset = pd.DataFrame(scale(dataset))

# %%
# Sample n observations from D : P

if sampling_size > dataset.shape[0]:
    raise Exception(
        'The number of sample of sample is bigger than the shape of D')

sample_dataset = dataset.sample(n=sampling_size)
sample_dataset.shape
# Out:
# (350, 10)

# %%
sample_dataset.head()
# Out:
#             0         1         2         3         4         5         6  \
# 447  0.315689  0.623244 -0.020852  1.081761  0.562208 -0.417052  5.112365
# 312  0.389260  0.404255 -0.422895  1.994737 -0.281905  0.087174 -0.205629
# 500 -0.444543 -0.468574 -0.422895 -0.132708 -0.281905 -0.136927 -0.205629
# 220 -0.481329 -0.484216 -0.422895 -0.384307 -0.281905 -0.435728  0.057530
# 497  0.475093 -0.377850 -0.288881  1.295143 -0.281905  0.684775 -0.205629
#
#             7         8         9
# 447  6.105498  4.790708 -0.201382
# 312 -0.001384 -0.442216 -0.013810
# 500 -0.183679 -0.442216 -0.382702
# 220 -0.183679  0.044568 -0.361861
# 497 -0.183679  0.653047 -0.099260

# %%
# Get the distance to their neirest neighbors in D : X

tree = BallTree(dataset, leaf_size=2)
dist, _ = tree.query(sample_dataset, k=2)
sample_knn_dist = dist[:, 1]

# %%
sample_knn_dist
# Out:
# array([1.98432335e+00, 1.24380464e+00, 1.65078318e-01, 2.80763145e-01,
#        1.27192284e+00, 1.43961009e-01, 7.13527214e-01, 1.56073992e+00,
#        7.88201973e-01, 2.54348827e+00, 6.08961683e-01, 1.01815988e-01,
#        1.12090617e-01, 2.12638560e-02, 3.12836941e-02, 1.28651724e-01,
#        0.00000000e+00, 1.27321961e+00, 3.12841782e-03, 2.52275265e-02,
#        0.00000000e+00, 6.86162104e-01, 1.64765904e-01, 0.00000000e+00,
#        8.53659731e-01, 7.76514413e-01, 2.03811404e+00, 0.00000000e+00,
#        2.93217870e-01, 9.22338609e+00, 2.94403752e+00, 1.06265084e+00,
#        0.00000000e+00, 7.28329460e-01, 4.46429525e-03, 2.00096472e-01,
#        1.28937023e+00, 7.15415690e-01, 3.58582262e-01, 1.29281065e-01,
#        5.17869113e-01, 1.82038519e-01, 2.93261373e+00, 1.31839299e-01,
#        1.04272414e-01, 1.30796992e-02, 0.00000000e+00, 7.80317828e-01,
#        2.53197552e-01, 8.10604407e-02, 1.51655223e-02, 7.32356156e-03,
#        9.07253083e-02, 3.78379091e-02, 2.53197552e-01, 1.79859330e+00,
#        3.38606227e-01, 1.41792324e+00, 4.30297107e+00, 3.67324157e-01,
#        0.00000000e+00, 5.67119991e-03, 3.43886463e-01, 4.79655236e-01,
#        3.80612160e-03, 3.32705481e-02, 2.12638560e-02, 7.04209396e-02,
#        1.24213180e+00, 2.08413714e-03, 4.70265848e-01, 2.39917867e+00,
#        2.38881198e-01, 1.70849333e+00, 3.84748089e-02, 6.76263433e-01,
#        4.84428267e-02, 7.87533554e-02, 1.08502095e+00, 6.57866677e-02,
#        3.30363296e-03, 0.00000000e+00, 4.15575684e-02, 1.09859246e-01,
#        1.18330578e+00, 2.33893572e-03, 1.01815988e-01, 2.75602037e-01,
#        6.75342808e-01, 5.44952346e-01, 6.09851746e-02, 5.84349355e-01,
#        6.94936222e-01, 1.04869383e-01, 1.69673211e-01, 0.00000000e+00,
#        5.62756423e-03, 1.77271333e+00, 0.00000000e+00, 6.85397542e-01,
#        3.12841782e-03, 2.40013245e-01, 5.08357458e-02, 8.28493101e-01,
#        1.69608565e-02, 5.24376437e-02, 2.24097319e+00, 1.67551443e-02,
#        2.14411993e-02, 1.44924459e-01, 6.09851746e-02, 9.22006936e-01,
#        5.89102923e-02, 0.00000000e+00, 2.64963473e-02, 1.78040069e-02,
#        5.22365505e-02, 2.45172932e-02, 9.68428717e-01, 2.40351124e-02,
#        3.80612160e-03, 4.67787143e-03, 1.70849333e+00, 8.63557147e+00,
#        1.11125774e-02, 0.00000000e+00, 4.15798983e-02, 2.89754961e-01,
#        1.40988030e+00, 5.85387663e-01, 1.43418414e-02, 7.40501754e-02,
#        4.48910002e-02, 1.13576679e+00, 1.26714855e-01, 2.88860417e-02,
#        1.00478488e+00, 1.04827806e+00, 6.29781052e-01, 3.42837054e-01,
#        1.08853347e-01, 1.43596995e-01, 1.91928332e-01, 2.12319822e-03,
#        1.60623702e-01, 1.81471642e-02, 1.06190596e-01, 1.72091518e+00,
#        2.97525133e-01, 6.85298391e-01, 3.81836746e-01, 5.62756423e-03,
#        6.34217377e-02, 7.19765020e-01, 4.91395561e-01, 1.95700061e-01,
#        2.00527036e+00, 2.67950208e-01, 1.05994124e+00, 9.06488510e-01,
#        1.72292368e+00, 1.81471642e-02, 3.12609282e-01, 1.44975519e+00,
#        7.76514413e-01, 5.13400709e-02, 5.26669139e-02, 1.11548206e+00,
#        1.21077912e-01, 2.81284194e+00, 3.93868197e-02, 1.08019625e+00,
#        0.00000000e+00, 5.95032715e-03, 3.74776685e+00, 1.64811693e+00,
#        1.00152818e-01, 1.38563474e-02, 5.59884771e-01, 6.94936222e-01,
#        2.33893572e-03, 1.34857713e+00, 0.00000000e+00, 1.81409909e-02,
#        3.78086878e-03, 1.66573575e-01, 5.76624545e-02, 3.58311387e+00,
#        2.79859665e-02, 1.06159911e-03, 5.50350707e-01, 2.33893572e-03,
#        3.96843994e-02, 8.09358527e-01, 7.45103786e-01, 1.59614857e+00,
#        1.44544272e+00, 2.05806382e-01, 0.00000000e+00, 3.72983524e-02,
#        8.63783511e-01, 1.22863383e-01, 1.43409038e-02, 1.64480840e+00,
#        2.75602037e-01, 0.00000000e+00, 1.87846317e-02, 3.84748089e-02,
#        1.07526346e-02, 0.00000000e+00, 5.48479239e-01, 3.81836746e-01,
#        2.14411993e-02, 4.90846646e+00, 2.02777829e-02, 0.00000000e+00,
#        4.15350717e-01, 1.27964801e+00, 4.63737317e-02, 2.92848482e-01,
#        1.19779621e+00, 2.04115495e-02, 3.50315690e-01, 2.40330236e-01,
#        7.72327120e-01, 4.24639644e-03, 4.92682045e-03, 1.04272414e-01,
#        1.68920308e+00, 9.22006936e-01, 4.92682045e-03, 0.00000000e+00,
#        5.93905157e-01, 5.79036287e+00, 0.00000000e+00, 1.08853347e-01,
#        3.98495585e-01, 2.45043610e+00, 1.44544272e+00, 0.00000000e+00,
#        1.47398650e-02, 2.31588838e-01, 0.00000000e+00, 7.04209396e-02,
#        7.02226866e-01, 3.44510785e-02, 1.67551443e-02, 1.05081060e+00,
#        1.43418414e-02, 2.88860417e-02, 1.78040069e-02, 8.93028337e-01,
#        0.00000000e+00, 7.95606783e-01, 2.15187188e-01, 4.15350717e-01,
#        0.00000000e+00, 2.81669321e-01, 1.12829639e+00, 6.61834747e-01,
#        3.78086878e-03, 1.39286773e-02, 5.64092479e-02, 2.62446086e-01,
#        2.27328781e-01, 5.72216674e-01, 6.43554386e-02, 2.81284194e+00,
#        2.50470205e-01, 1.98432335e+00, 7.32356156e-03, 2.92296178e-01,
#        0.00000000e+00, 3.35312962e-01, 7.51018508e-02, 5.21047071e-01,
#        5.44952346e-01, 8.28493101e-01, 9.90934965e-01, 7.72327120e-01,
#        1.02687480e-01, 2.92370960e-01, 6.29781052e-01, 1.23717492e+00,
#        9.05409943e-02, 1.18437479e+00, 8.63783511e-01, 2.66010591e-01,
#        1.43035795e-02, 3.12836941e-02, 3.92000065e-01, 2.93217870e-01,
#        1.46759803e+00, 8.44251662e-01, 1.39738131e-02, 7.51018508e-02,
#        3.68091254e-02, 0.00000000e+00, 2.67950208e-01, 2.12319822e-03,
#        1.39108446e+00, 3.30363296e-03, 1.10564771e+00, 5.59884771e-01,
#        0.00000000e+00, 8.83819398e-01, 2.40013245e-01, 3.27588901e+00,
#        1.14751856e-01, 1.21282462e+00, 3.38324110e-02, 1.77706403e-02,
#        4.58578370e-02, 3.74827298e-02, 3.24135183e-01, 2.14374046e+00,
#        9.55439198e-03, 3.44510785e-02, 3.24135183e-01, 7.56173756e-03,
#        7.28329460e-01, 1.62311660e-02, 2.96304078e-01, 3.41071097e-01,
#        2.00096472e-01, 2.67746397e-01, 0.00000000e+00, 3.75525311e-02,
#        1.19779621e+00, 5.46653394e-02, 1.28314870e-02, 5.85387663e-01,
#        3.30363296e-03, 2.33071594e-02, 1.78995868e-01, 6.25241142e-03,
#        3.79739988e-01, 1.13745745e-01, 2.76572146e-01, 1.64811693e+00,
#        1.76785313e-01, 7.95606783e-01, 0.00000000e+00, 4.91395561e-01,
#        3.06126866e-02, 1.24442782e-02, 3.38324110e-02, 0.00000000e+00,
#        4.46429525e-03, 2.05419374e+00])

# %%
# Randomly simulate n points with the same variation as in D : Q.

max_data = dataset.max()
min_data = dataset.min()

uniform_sel_x = np.random.uniform(min_data[0], max_data[0], sampling_size)
uniform_sel_y = np.random.uniform(min_data[1], max_data[1], sampling_size)

uniform_obsv = np.column_stack((uniform_sel_x, uniform_sel_y))
if len(max_data) >= 2:
    for i in range(2, len(max_data)):
        temp = np.random.uniform(min_data[i], max_data[i], sampling_size)
        to_stack = (uniform_obsv, temp)
        uniform_obsv = np.column_stack(to_stack)

uniform_obsv_df = pd.DataFrame(uniform_obsv)
uniform_obsv_df.columns = dataset.columns

# %%
uniform_obsv_df.shape
# Out:
# (350, 10)

# %%
uniform_obsv_df.head()
# Out:
#           0         1         2         3         4         5          6  \
# 0  1.177442  4.952025 -0.025218  3.843219  3.749885  1.917612   0.080730
# 1  5.388605  1.094842  2.422359  4.935218  9.240526  2.626178  12.884304
# 2  1.174849  0.009273  7.351570  0.922745  4.356972  0.190388   9.314885
# 3  6.071437  4.231859  7.472364  0.406209  6.812481  2.345910  10.915020
# 4  1.001363  2.133695  3.570910  4.181020  0.005408  1.928006   5.748648
#
#            7         8         9
# 0   2.575391  1.307402  2.801802
# 1  10.115116  2.575047  6.187084
# 2   8.039558  7.054870 -0.194636
# 3   3.746295 -0.043107  1.231912
# 4   4.454780  3.512980  2.041900

# %%
# Get the distance to their neirest neighbors in D : Y

tree = BallTree(dataset, leaf_size=2)
dist, _ = tree.query(uniform_obsv_df, k=1)
uniform_knn_dist = dist

# %%
# Calculate the Hopkins Score

x = sum(sample_knn_dist)
y = sum(uniform_knn_dist)

if x + y == 0:
    raise Exception('The denominator of the hopkins statistics is null')

h_stat = (y[0] / (x + y)[0])
print ("The hopkins statistics measure is {}".format(h_stat))
# Out:
# The hopkins statistics measure is 0.9529207904947263
